# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

# %%
df1=pd.read_csv("df1",index_col=0)
df2=pd.read_csv("df2")
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].hist()

# %%
plt.style.use('ggplot')
df1["A"].hist()

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()

# %%
df1["A"].plot.hist()

# %%
df2.plot.area()

# %%
df1.plot.line(y="A",figsize=(13,2),lw=1)

# %%
type(df1["C"])
# Out:
# pandas.core.series.Series

# %%
df1.plot.scatter(x="A",y="B",s=df1["C"]*200,cmap="coolwarm")
# Out:
# c:\users\mohit\appdata\local\programs\python\python37-32\lib\site-packages\matplotlib\collections.py:902: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
dict1={'a':[100,200]}
x=pd.DataFrame(dict1,index=["c","d"])
x
# Out:
#      a
# c  100
# d  200

# %%
y=pd.DataFrame(data=[0,1],columns=["a"],index=["c","d"])
y
# Out:
#    a
# c  0
# d  1

# %%
np.random.randn(1000, 2)
# Out:
# array([[-0.353583  ,  0.89281608],
#        [-0.85805206,  0.01325439],
#        [ 1.76919737, -0.99694142],
#        ...,
#        [-0.46148066, -0.81468234],
#        [ 0.03200372, -1.55019954],
#        [-3.57610878, -0.73530063]])

# %%
df1.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %%
x.loc["c"]
# Out:
# a    100
# Name: c, dtype: int64

# %%
df1.iloc[0]
# Out:
# A    1.339091
# B   -0.163643
# C   -0.646443
# D    1.041233
# Name: 2000-01-01, dtype: float64

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.index.nunique()
# Out:
# 1000
